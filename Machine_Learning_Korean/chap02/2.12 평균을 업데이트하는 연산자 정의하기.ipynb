# %%
update_avg = alpha * curr_value + (1 - alpha) * prev_avg # alpha는 tf.constant, curr_value는 플레이스홀더, prev_avg는 변수입니다
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-66cb9c13079e> in <module>()
# ----> 1 update_avg = alpha * curr_value + (1 - alpha) * prev_avg # alpha는 tf.constant, curr_value는 플레이스홀더, prev_avg는 변수입니다
#
# NameError: name 'alpha' is not defined
